# %% [markdown]
# # How to pass run time values to tools

# %% [markdown]
# This guide explains how to safely and effectively pass runtime values to tools in LangChain, particularly when certain arguments (like user_id) need to be injected by application logic instead of being generated by a language model. Here's a breakdown of the concepts and steps:

# %% [markdown]
# # Overview
# 1. Why inject runtime values?
#
# * Some parameters (like user_id) should not be controlled by the LLM to avoid security risks.
# * The LLM should only control the parameters it is meant to, such as those related to natural language inputs.
#
# 2. Key Mechanism: InjectedToolArg
#
# * This annotation marks parameters as injected at runtime, ensuring the LLM does not generate or control these values.

# %% [markdown]
# # How It Works
# 1. Creating Tools with Runtime-Injected Arguments
# * Use the @tool decorator from langchain_core.tools to define tools.
# * Annotate arguments with InjectedToolArg to indicate they’ll be provided at runtime.

# %%
from langchain_core.tools import InjectedToolArg, tool
from typing_extensions import Annotated
from typing import List

user_to_pets = {}

@tool(parse_docstring=True)
def update_favorite_pets(pets: List[str], user_id: Annotated[str, InjectedToolArg]) -> None:
    """
    Add a list of favorite pets for the user.

    Args:
        pets (List[str]): A list of pets to be added as favorites.
        user_id (str): The ID of the user, injected by the tool.
    """
    user_to_pets[user_id] = pets
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 8
#       3 from typing import List
#       5 user_to_pets = {}
#       7 @tool(parse_docstring=True)
# ----> 8 def update_favorite_pets(pets: List[str], user_id: Annotated[str, InjectedToolArg]) -> None:
#       9     """
#      10     Add a list of favorite pets for the user.
#      11
#    (...)
#      14         user_id (str): The ID of the user, injected by the tool.
#      15     """
#      16     user_to_pets[user_id] = pets
#
# File c:\Users\Admin\Desktop\10-20-2024\venv\lib\site-packages\langchain_core\tools\convert.py:332, in tool.<locals>._partial(func)
#     330 name_ = func.get_name() if isinstance(func, Runnable) else func.__name__
#     331 tool_factory = _create_tool_factory(name_)
# --> 332 return tool_factory(func)
#
# File c:\Users\Admin\Desktop\10-20-2024\venv\lib\site-packages\langchain_core\tools\convert.py:249, in tool.<locals>._create_tool_factory.<locals>._tool_factory(dec_func)
#     246     description = None
#     248 if infer_schema or args_schema is not None:
# --> 249     return StructuredTool.from_function(
#     250         func,
#     251         coroutine,
#     252         name=tool_name,
#     253         description=description,
#     254         return_direct=return_direct,
#     255         args_schema=schema,
#     256         infer_schema=infer_schema,
#     257         response_format=response_format,
#     258         parse_docstring=parse_docstring,
#     259         error_on_invalid_docstring=error_on_invalid_docstring,
#     260     )
#     261 # If someone doesn't want a schema applied, we must treat it as
#     262 # a simple string->string function
#     263 if dec_func.__doc__ is None:
#
# File c:\Users\Admin\Desktop\10-20-2024\venv\lib\site-packages\langchain_core\tools\structured.py:176, in StructuredTool.from_function(cls, func, coroutine, name, description, return_direct, args_schema, infer_schema, response_format, parse_docstring, error_on_invalid_docstring, **kwargs)
#     173 name = name or source_function.__name__
#     174 if args_schema is None and infer_schema:
#     175     # schema name is appended within function
# --> 176     args_schema = create_schema_from_function(
#     177         name,
#     178         source_function,
#     179         parse_docstring=parse_docstring,
#     180         error_on_invalid_docstring=error_on_invalid_docstring,
#     181         filter_args=_filter_schema_args(source_function),
#     182     )
#     183 description_ = description
#     184 if description is None and not parse_docstring:
#
# File c:\Users\Admin\Desktop\10-20-2024\venv\lib\site-packages\langchain_core\tools\base.py:282, in create_schema_from_function(model_name, func, filter_args, parse_docstring, error_on_invalid_docstring, include_injected)
#     277         if not include_injected and _is_injected_arg_type(
#     278             sig.parameters[existing_param].annotation
#     279         ):
#     280             filter_args_.append(existing_param)
# --> 282 description, arg_descriptions = _infer_arg_descriptions(
#     283     func,
#     284     parse_docstring=parse_docstring,
#     285     error_on_invalid_docstring=error_on_invalid_docstring,
#     286 )
#     287 # Pydantic adds placeholder virtual fields we need to strip
#     288 valid_properties = []
#
# File c:\Users\Admin\Desktop\10-20-2024\venv\lib\site-packages\langchain_core\tools\base.py:155, in _infer_arg_descriptions(fn, parse_docstring, error_on_invalid_docstring)
#     153     arg_descriptions = {}
#     154 if parse_docstring:
# --> 155     _validate_docstring_args_against_annotations(arg_descriptions, annotations)
#     156 for arg, arg_type in annotations.items():
#     157     if arg in arg_descriptions:
#
# File c:\Users\Admin\Desktop\10-20-2024\venv\lib\site-packages\langchain_core\tools\base.py:132, in _validate_docstring_args_against_annotations(arg_descriptions, annotations)
#     130 if docstring_arg not in annotations:
#     131     msg = f"Arg {docstring_arg} in docstring not found in function signature."
# --> 132     raise ValueError(msg)
#
# ValueError: Arg pets (List[str]) in docstring not found in function signature.
